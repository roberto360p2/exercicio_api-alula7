# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Seu código aqui
url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=RJ&tipo_interessado=Munic%C3%ADpio'
df = requests.get(url)
df = df.json()
print(df["items"])
# Out:
# [{'id_pleito': 6390, 'tipo_interessado': 'Município', 'interessado': 'Cantagalo', 'cod_ibge': 3301108, 'uf': 'RJ', 'num_pvl': None, 'status': 'Arquivado', 'num_processo': '17944.000335/2008-36', 'data_protocolo': '2008-04-10T03:00:00Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Caminho da Escola', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Banco do Brasil S/A', 'moeda': 'Real', 'valor': 483160, 'pvl_assoc_divida': 0, 'pvl_contradado_credor': 0, 'data_status': '14/05/2008'}, {'id_pleito': 60039, 'tipo_interessado': 'Município', 'interessado': 'Petrópolis', 'cod_ibge': 3303906, 'uf': 'RJ', 'num_pvl': 'PVL02.005942/2022-88', 'status': 'Em análise', 'num_processo': '17944.102384/2022-61', 'data_protocolo': '2022-06-21T13:12:44Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Infraestrutura', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Caixa Econômica Federal', 'moeda': 'Real', 'valor': 20000000, 'pvl_assoc_divida': 
# ...

# %%
# 2) Seu código aqui
df = pd.DataFrame(df['items'])
df
# Out:
#      id_pleito tipo_interessado           interessado  cod_ibge  uf  \
# 0         6390        Município             Cantagalo   3301108  RJ
# 1        60039        Município            Petrópolis   3303906  RJ
# 2        34869        Município           Nova Iguaçu   3303500  RJ
# 3        41862        Município  Santa Maria Madalena   3304607  RJ
# 4        45530        Município     Casimiro de Abreu   3301306  RJ
# ..         ...              ...                   ...       ...  ..
# 223      22824        Município        Rio de Janeiro   3304557  RJ
# 224       8643        Município        Rio de Janeiro   3304557  RJ
# 225      11707        Município    São João de Meriti   3305109  RJ
# 226      10263        Município    Armação dos Búzios   3300233  RJ
# 227      12078        Município               Resende   3304201  RJ
#
#                   num_pvl                                             status  \
# ...

# %%
df["status"].value_counts()
# Out:
# Deferido                                                 89
# Arquivado                                                53
# Regularizado                                             25
# Arquivado por decurso de prazo                           23
# Deferido (PVL-IF)                                        14
# Encaminhado à PGFN com manifestação técnica favorável    11
# Arquivado a pedido                                        5
# Em análise                                                3
# Em retificação pelo interessado                           3
# Em retificação pelo interessado (PVL-IF)                  1
# Pendente de regularização                                 1
# Name: status, dtype: int64

# %%
# 3) Seu código aqui
ano2022 = df[df["data_status"]>'01/01/2022']
ano2022
# Out:
#      id_pleito tipo_interessado           interessado  cod_ibge  uf  \
# 0         6390        Município             Cantagalo   3301108  RJ
# 1        60039        Município            Petrópolis   3303906  RJ
# 2        34869        Município           Nova Iguaçu   3303500  RJ
# 3        41862        Município  Santa Maria Madalena   3304607  RJ
# 4        45530        Município     Casimiro de Abreu   3301306  RJ
# ..         ...              ...                   ...       ...  ..
# 223      22824        Município        Rio de Janeiro   3304557  RJ
# 224       8643        Município        Rio de Janeiro   3304557  RJ
# 225      11707        Município    São João de Meriti   3305109  RJ
# 226      10263        Município    Armação dos Búzios   3300233  RJ
# 227      12078        Município               Resende   3304201  RJ
#
#                   num_pvl                                             status  \
# ...

# %%
df["data_status"].value_counts()
# Out:
# 25/05/2007    6
# 30/10/2008    5
# 02/08/2007    5
# 15/09/2008    4
# 29/06/2012    4
#              ..
# 09/07/2010    1
# 17/08/2017    1
# 17/07/2007    1
# 15/07/2010    1
# 20/12/2010    1
# Name: data_status, Length: 170, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) Seu código aqui
url2 = "https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=MG&tipo_interessado=Estado"
df2 = requests.get(url2)
df2 = df2.json()
df2 = pd.DataFrame(df2["items"])
df2
# Out:
#     id_pleito tipo_interessado   interessado  cod_ibge  uf  \
# 0        4926           Estado  Minas Gerais        31  MG
# 1       12286           Estado  Minas Gerais        31  MG
# 2       13275           Estado  Minas Gerais        31  MG
# 3       11571           Estado  Minas Gerais        31  MG
# 4       11132           Estado  Minas Gerais        31  MG
# 5       13602           Estado  Minas Gerais        31  MG
# 6       10011           Estado  Minas Gerais        31  MG
# 7        6811           Estado  Minas Gerais        31  MG
# 8        5828           Estado  Minas Gerais        31  MG
# 9        7280           Estado  Minas Gerais        31  MG
# 10       7023           Estado  Minas Gerais        31  MG
# 11      13441           Estado  Minas Gerais        31  MG
# 12      11696           Estado  Minas Gerais        31  MG
# 13       5967           Estado  Minas Gerais        31  MG
# 14       7002           Estado  Minas Gerais        31  MG
# ...

# %%
# 2) Seu código aqui
df2[df2["uf"]=="MG"]["status"].value_counts()
# Out:
# Encaminhado à PGFN com manifestação técnica favorável    20
# Deferido                                                  7
# Arquivado a pedido                                        5
# Arquivado pela STN                                        3
# Arquivado                                                 3
# Indeferido                                                1
# Arquivado por decurso de prazo                            1
# Name: status, dtype: int64

# %%
# 3) Seu código aqui
url3 = "https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=BA&tipo_interessado=Estado"
df3 = requests.get(url3)
df3 = df3.json()
df3 = pd.DataFrame(df3["items"])
df3
# Out:
#     id_pleito tipo_interessado interessado  cod_ibge  uf  \
# 0       40577           Estado       Bahia        29  BA
# 1        8535           Estado       Bahia        29  BA
# 2       10528           Estado       Bahia        29  BA
# 3       18368           Estado       Bahia        29  BA
# 4       18389           Estado       Bahia        29  BA
# ..        ...              ...         ...       ...  ..
# 76      18441           Estado       Bahia        29  BA
# 77      18583           Estado       Bahia        29  BA
# 78      10420           Estado       Bahia        29  BA
# 79       9412           Estado       Bahia        29  BA
# 80      18550           Estado       Bahia        29  BA
#
#                  num_pvl                                             status  \
# 0   PVL02.008660/2019-37  Encaminhado à PGFN com manifestação técnica fa...
# 1                   None  Encaminhado à PGFN com manifestação técnica fa...
# ...

# %%
df3[df3["status"]=="Deferido"]["id_pleito"].value_counts()
# Out:
# 18559    1
# 10198    1
# 18527    1
# 18589    1
# 18507    1
# 18587    1
# 5593     1
# 18519    1
# 43670    1
# 18389    1
# 18579    1
# 6610     1
# 44369    1
# 8336     1
# 18575    1
# 18571    1
# 18591    1
# 18633    1
# 18447    1
# 18567    1
# 18372    1
# 18499    1
# 18583    1
# 18592    1
# 18595    1
# 18495    1
# 18441    1
# 10557    1
# 18555    1
# 11514    1
# 8342     1
# 18531    1
# 18551    1
# 9412     1
# 42037    1
# 5620     1
# 18547    1
# 18550    1
# 18511    1
# 7078     1
# 18543    1
# 18523    1
# 20438    1
# 18539    1
# 10859    1
# 18503    1
# 18535    1
# 18515    1
# 18368    1
# Name: id_pleito, dtype: int64

# %%
# 4) Seu código aqui
df3.to_csv(r"estadoBahia.csv",sep=';',decimal=",",index=False,encoding="utf8")
